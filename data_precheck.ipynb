# %%
from pathlib import Path
import pandas as pd
import re

# %%
# Set the folder that contains all CSV files
data_dir = Path("csv")

# Set the output folder for combined files
output_dir = Path("output")
output_dir.mkdir(exist_ok=True)

# %%
def print_section(title):
    """
    Print a clean section title.
    """
    print("\n" + "-" * 50)
    print(title)
    print("-" * 50)


def extract_year_month(file):
    """
    Extract year-month information from the file name.
    Example: CRMLSSold202403.csv -> 202403
    """
    match = re.search(r"(\d{6})", file.stem)
    return match.group(1) if match else None


def is_filled_file(file):
    """
    Check whether the file is a filled file.
    """
    return "_filled" in file.name.lower()


def select_files_by_month(files, label):
    """
    Select one file for each year-month.

    Logic:
    1. If both original and filled files exist for the same month,
       use the original file.
    2. If only the filled file exists for that month,
       use the filled file.
    """
    selected_files = {}

    for file in files:
        ym = extract_year_month(file)

        if ym is None:
            print(f"Warning: Cannot extract year-month from {label} file:", file.name)
            continue

        current_is_filled = is_filled_file(file)

        # If this month has not been selected yet, add the file
        if ym not in selected_files:
            selected_files[ym] = file

        else:
            existing_file = selected_files[ym]
            existing_is_filled = is_filled_file(existing_file)

            # If the existing selected file is filled,
            # but the current file is original, replace it
            if existing_is_filled and not current_is_filled:
                selected_files[ym] = file

            # If both are original or both are filled, keep the first one
            else:
                print(f"Warning: Duplicate {label} files for {ym}. Keeping:", selected_files[ym].name)
                print("Ignored:", file.name)

    return sorted(selected_files.values())

# %%
print("Current working folder:", Path.cwd())
print("CSV folder exists:", data_dir.exists())
# Out:
# Current working folder: /Users/linda/Downloads/IDX_Data_Analyst_Intern/da53_project
# CSV folder exists: True

# %%
# Stop the program if the csv folder does not exist
if not data_dir.exists():
    raise FileNotFoundError(
        "Cannot find csv folder. Make sure you run this code inside DA53_PROJECT "
        "and check whether your folder name is csv or CSV."
    )

# %%
# --------------------------------------------------
# 1. Find Sold and List files
# --------------------------------------------------

# Find all Sold and List files, including filled files
all_sold_files = sorted(data_dir.rglob("*Sold*.csv"))
all_list_files = sorted(data_dir.rglob("*List*.csv"))

# Select one file per month
# Original file is preferred, but filled file will be used if original is missing
sold_files = select_files_by_month(all_sold_files, "Sold")
list_files = select_files_by_month(all_list_files, "List")


print_section("1. File Count Check")

print("All Sold files found:", len(all_sold_files))
print("All List files found:", len(all_list_files))

print("Sold files selected:", len(sold_files))
print("List files selected:", len(list_files))

if len(sold_files) == 0:
    print("Warning: No Sold files found.")

if len(list_files) == 0:
    print("Warning: No List files found.")
# Out:
# Warning: Duplicate Sold files for 202401. Keeping: CRMLSSold202401.csv
# Ignored: CRMLSSold202401_filled.csv
# Warning: Duplicate Sold files for 202403. Keeping: CRMLSSold202403.csv
# Ignored: CRMLSSold202403_filled.csv
# Warning: Duplicate Sold files for 202404. Keeping: CRMLSSold202404.csv
# Ignored: CRMLSSold202404_filled.csv
#
# --------------------------------------------------
# 1. File Count Check
# --------------------------------------------------
# All Sold files found: 33
# All List files found: 30
# Sold files selected: 30
# List files selected: 30

# %%
print_section("2. File Name Check")

print("\nSold files selected:")
for f in sold_files:
    file_type = "filled" if is_filled_file(f) else "original"
    print(f"{f.name}  |  {file_type}")

print("\nList files selected:")
for f in list_files:
    file_type = "filled" if is_filled_file(f) else "original"
    print(f"{f.name}  |  {file_type}")
# Out:
# --------------------------------------------------
# 2. File Name Check
# --------------------------------------------------
#
# Sold files selected:
# CRMLSSold202401.csv  |  original
# CRMLSSold202402.csv  |  original
# CRMLSSold202403.csv  |  original
# CRMLSSold202404.csv  |  original
# CRMLSSold202405_filled.csv  |  filled
# CRMLSSold202406_filled.csv  |  filled
# CRMLSSold202407_filled.csv  |  filled
# CRMLSSold202408.csv  |  original
# CRMLSSold202409.csv  |  original
# CRMLSSold202410.csv  |  original
# CRMLSSold202411.csv  |  original
# CRMLSSold202412.csv  |  original
# CRMLSSold202501_filled.csv  |  filled
# CRMLSSold202502.csv  |  original
# CRMLSSold202503.csv  |  original
# CRMLSSold202504.csv  |  original
# CRMLSSold202505.csv  |  original
# CRMLSSold202506.csv  |  original
# CRMLSSold202507.csv  |  original
# CRMLSSold202508.csv  |  original
# CRMLSSold202509.csv  |  original
# CRMLSSold202510.csv  |  original
# CRMLSSold202511.csv  |  original
# CRMLSSold202512.csv  |  original
# CRMLSSold202601.csv  |  original
# CRMLSSold202602.csv  |  original
# CRMLSSold202603.csv  |  original
# CRMLSSold202604.csv  |  original
# CRMLSSold202605.csv  |  original
# CRMLSSold202606.csv  |  original
#
# List files selected:
# CRMLSListing202401.csv  |  original
# CRMLSListing202402.csv  |  original
# CRMLSListing202403.csv  |  original
# CRMLSListing202404.csv  |  original
# CRMLSListing202405.csv  |  original
# CRMLSListing202406.csv  |  original
# CRMLSListing202407.csv  |  original
# CRMLSListing202408.csv  |  original
# CRMLSListing202409.csv  |  original
# CRMLSListing202410.csv  |  original
# CRMLSListing202411.csv  |  original
# CRMLSListing202412.csv  |  original
# CRMLSListing202501.csv  |  original
# CRMLSListing202502.csv  |  original
# CRMLSListing202503.csv  |  original
# CRMLSListing202504.csv  |  original
# CRMLSListing202505.csv  |  original
# CRMLSListing202506.csv  |  original
# CRMLSListing202507.csv  |  original
# CRMLSListing202508.csv  |  original
# CRMLSListing202509.csv  |  original
# CRMLSListing202510.csv  |  original
# CRMLSListing202511.csv  |  original
# CRMLSListing202512.csv  |  original
# CRMLSListing202601.csv  |  original
# CRMLSListing202602.csv  |  original
# CRMLSListing202603.csv  |  original
# CRMLSListing202604.csv  |  original
# CRMLSListing202605.csv  |  original
# CRMLSListing202606.csv  |  original

# %%
print_section("3. Year-Month Check")

sold_months = [extract_year_month(f) for f in sold_files]
list_months = [extract_year_month(f) for f in list_files]

print("Sold months count:", len(sold_months))
print("List months count:", len(list_months))

print("\nSold months:")
print(sold_months)

print("\nList months:")
print(list_months)

# Check if any selected file name does not contain year-month information
sold_no_month = [f.name for f in sold_files if extract_year_month(f) is None]
list_no_month = [f.name for f in list_files if extract_year_month(f) is None]

if sold_no_month:
    print("\nSold files without year-month:")
    print(sold_no_month)

if list_no_month:
    print("\nList files without year-month:")
    print(list_no_month)
# Out:
# --------------------------------------------------
# 3. Year-Month Check
# --------------------------------------------------
# Sold months count: 30
# List months count: 30
#
# Sold months:
# ['202401', '202402', '202403', '202404', '202405', '202406', '202407', '202408', '202409', '202410', '202411', '202412', '202501', '202502', '202503', '202504', '202505', '202506', '202507', '202508', '202509', '202510', '202511', '202512', '202601', '202602', '202603', '202604', '202605', '202606']
#
# List months:
# ['202401', '202402', '202403', '202404', '202405', '202406', '202407', '202408', '202409', '202410', '202411', '202412', '202501', '202502', '202503', '202504', '202505', '202506', '202507', '202508', '202509', '202510', '202511', '202512', '202601', '202602', '202603', '202604', '202605', '202606']

# %%
# Compare year-month coverage between Sold and List files
sold_month_set = set(sold_months)
list_month_set = set(list_months)

print("\nMonths in Sold but not in List:")
print(sorted(sold_month_set - list_month_set))

print("\nMonths in List but not in Sold:")
print(sorted(list_month_set - sold_month_set))
# Out:
# Months in Sold but not in List:
# []
#
# Months in List but not in Sold:
# []

# %%
def check_duplicate_months(files, label):
    """
    Check whether there are duplicate files for the same year-month.
    This check is done after file selection.
    """
    month_count = {}

    for file in files:
        ym = extract_year_month(file)
        month_count[ym] = month_count.get(ym, 0) + 1

    duplicates = {month: count for month, count in month_count.items() if count > 1}

    if duplicates:
        print(f"\nDuplicate year-months in selected {label} files:")
        print(duplicates)
    else:
        print(f"\nNo duplicate year-months in selected {label} files.")


check_duplicate_months(sold_files, "Sold")
check_duplicate_months(list_files, "List")


print_section("4. Row Count Check")


def check_row_counts(files, label):
    """
    Count the number of rows in each CSV file.
    Only the first column is loaded to make the check faster.
    """
    result = []

    for file in files:
        try:
            df = pd.read_csv(file, usecols=[0], low_memory=False)
            row_count = len(df)

            result.append({
                "file_name": file.name,
                "file_version": "filled" if is_filled_file(file) else "original",
                "year_month": extract_year_month(file),
                "rows": row_count
            })

        except Exception as e:
            result.append({
                "file_name": file.name,
                "file_version": "filled" if is_filled_file(file) else "original",
                "year_month": extract_year_month(file),
                "rows": "ERROR",
                "error": str(e)
            })

    row_df = pd.DataFrame(result)

    print(f"\n{label} row counts:")
    print(row_df.to_string(index=False))

    numeric_rows = pd.to_numeric(row_df["rows"], errors="coerce")

    print(f"\n{label} total rows:", numeric_rows.sum())
    print(f"{label} min rows:", numeric_rows.min())
    print(f"{label} max rows:", numeric_rows.max())

    empty_files = row_df[numeric_rows == 0]
    if len(empty_files) > 0:
        print(f"\nWarning: {label} has empty files:")
        print(empty_files["file_name"].to_list())

    return row_df


sold_row_check = check_row_counts(sold_files, "Sold")
list_row_check = check_row_counts(list_files, "List")
# Out:
# No duplicate year-months in selected Sold files.
#
# No duplicate year-months in selected List files.
#
# --------------------------------------------------
# 4. Row Count Check
# --------------------------------------------------
#
# Sold row counts:
#                  file_name file_version year_month  rows
#        CRMLSSold202401.csv     original     202401 17976
#        CRMLSSold202402.csv     original     202402 19925
#        CRMLSSold202403.csv     original     202403 23276
#        CRMLSSold202404.csv     original     202404 24640
# CRMLSSold202405_filled.csv       filled     202405 26487
# CRMLSSold202406_filled.csv       filled     202406 24328
# CRMLSSold202407_filled.csv       filled     202407 26240
#        CRMLSSold202408.csv     original     202408 24558
#        CRMLSSold202409.csv     original     202409 21267
#        CRMLSSold202410.csv     original     202410 23274
#        CRMLSSold202411.csv     original     202411 20279
#        CRMLSSold202412.csv     original     202412 20241
# CRMLSSold202501_filled.csv       filled     202501 18738
#        CRMLSSold202502.csv     original     202502 18702
#        CRMLSSold202503.csv     original     202503 21445
#        CRMLSSold202504.csv     original     202504 23262
#        CRMLSSold202505.csv     original     202505 23154
#        CRMLSSold202506.csv     original     202506 22883
#        CRMLSSold202507.csv     original     202507 23646
#        CRMLSSold202508.csv     original     202508 22972
#        CRMLSSold202509.csv     original     202509 22443
#        CRMLSSold202510.csv     original     202510 23233
#        CRMLSSold202511.csv     original     202511 19088
#        CRMLSSold202512.csv     original     202512 20538
#        CRMLSSold202601.csv     original     202601 16487
#        CRMLSSold202602.csv     original     202602 19010
#        CRMLSSold202603.csv     original     202603 23372
#        CRMLSSold202604.csv     original     202604 24261
#        CRMLSSold202605.csv     original     202605 24195
#        CRMLSSold202606.csv     original     202606 25601
#
# Sold total rows: 665521
# Sold min rows: 16487
# Sold max rows: 26487
#
# List row counts:
#              file_name file_version year_month  rows
# CRMLSListing202401.csv     original     202401 27454
# CRMLSListing202402.csv     original     202402 27447
# CRMLSListing202403.csv     original     202403 32282
# CRMLSListing202404.csv     original     202404 36503
# CRMLSListing202405.csv     original     202405 38796
# CRMLSListing202406.csv     original     202406 35893
# CRMLSListing202407.csv     original     202407 36340
# CRMLSListing202408.csv     original     202408 35305
# CRMLSListing202409.csv     original     202409 34625
# CRMLSListing202410.csv     original     202410 34730
# CRMLSListing202411.csv     original     202411 25128
# CRMLSListing202412.csv     original     202412 19417
# CRMLSListing202501.csv     original     202501 37469
# CRMLSListing202502.csv     original     202502 33983
# CRMLSListing202503.csv     original     202503 38492
# CRMLSListing202504.csv     original     202504 40187
# CRMLSListing202505.csv     original     202505 40271
# CRMLSListing202506.csv     original     202506 26399
# CRMLSListing202507.csv     original     202507 27345
# CRMLSListing202508.csv     original     202508 25210
# CRMLSListing202509.csv     original     202509 26923
# CRMLSListing202510.csv     original     202510 27586
# CRMLSListing202511.csv     original     202511 20677
# CRMLSListing202512.csv     original     202512 18773
# CRMLSListing202601.csv     original     202601 35302
# CRMLSListing202602.csv     original     202602 32884
# CRMLSListing202603.csv     original     202603 39153
# CRMLSListing202604.csv     original     202604 39020
# CRMLSListing202605.csv     original     202605 36115
# CRMLSListing202606.csv     original     202606 37495
#
# List total rows: 967204
# List min rows: 18773
# List max rows: 40271

# %%
print_section("5. Column Consistency Check")


def check_columns(files, label):
    """
    Check whether all selected files have the same columns and column order.
    Filled files may have extra columns, such as latfilled and lonfilled.
    """
    if len(files) == 0:
        print(f"No {label} files found.")
        return {}

    columns_dict = {}

    for file in files:
        try:
            df = pd.read_csv(file, nrows=0)
            columns_dict[file.name] = list(df.columns)
        except Exception as e:
            print(f"Error reading columns from {file.name}: {e}")

    first_file = list(columns_dict.keys())[0]
    base_cols = columns_dict[first_file]

    print(f"\nChecking {label} columns...")
    print("Base file:", first_file)
    print("Base column count:", len(base_cols))

    all_same = True

    for file_name, cols in columns_dict.items():
        missing_cols = sorted(set(base_cols) - set(cols))
        extra_cols = sorted(set(cols) - set(base_cols))

        if missing_cols or extra_cols:
            all_same = False
            print("\nColumns different:", file_name)
            print("Column count:", len(cols))
            print("Missing columns:", missing_cols)
            print("Extra columns:", extra_cols)

        elif cols != base_cols:
            all_same = False
            print("\nSame columns but different order:", file_name)

    if all_same:
        print(f"All {label} files have the same columns and same order.")
    else:
        print(f"\nNote: Some {label} files have different columns.")
        print("This is okay if the differences come from filled files.")
        print("When combining files, missing columns will be filled with NaN.")

    return columns_dict


sold_columns = check_columns(sold_files, "Sold")
list_columns = check_columns(list_files, "List")
# Out:
# --------------------------------------------------
# 5. Column Consistency Check
# --------------------------------------------------
#
# Checking Sold columns...
# Base file: CRMLSSold202401.csv
# Base column count: 80
#
# Columns different: CRMLSSold202402.csv
# Column count: 78
# Missing columns: ['BuyerAgentAOR', 'ListAgentAOR', 'OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
#
# Columns different: CRMLSSold202403.csv
# Column count: 78
# Missing columns: ['BuyerAgentAOR', 'ListAgentAOR', 'OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
#
# Columns different: CRMLSSold202404.csv
# Column count: 78
# Missing columns: ['BuyerAgentAOR', 'ListAgentAOR', 'OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
#
# Columns different: CRMLSSold202405_filled.csv
# Column count: 80
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: ['latfilled', 'lonfilled']
#
# Columns different: CRMLSSold202406_filled.csv
# Column count: 80
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: ['latfilled', 'lonfilled']
#
# Columns different: CRMLSSold202407_filled.csv
# Column count: 80
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: ['latfilled', 'lonfilled']
#
# Columns different: CRMLSSold202408.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202409.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202410.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202411.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202412.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202501_filled.csv
# Column count: 80
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: ['latfilled', 'lonfilled']
#
# Columns different: CRMLSSold202502.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202503.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202504.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202505.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202506.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202507.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202508.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202509.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202510.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202511.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202512.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202601.csv
# Column count: 78
# Missing columns: ['OriginatingSystemName', 'OriginatingSystemSubName']
# Extra columns: []
#
# Columns different: CRMLSSold202605.csv
# Column count: 79
# Missing columns: ['ListAgentEmail']
# Extra columns: []
#
# Columns different: CRMLSSold202606.csv
# Column count: 79
# Missing columns: ['ListAgentEmail']
# Extra columns: []
#
# Note: Some Sold files have different columns.
# This is okay if the differences come from filled files.
# When combining files, missing columns will be filled with NaN.
#
# Checking List columns...
# Base file: CRMLSListing202401.csv
# Base column count: 84
#
# Columns different: CRMLSListing202405.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202406.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202407.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202408.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202409.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202410.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202411.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202412.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202501.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202502.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202503.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202504.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202505.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202506.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202507.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202508.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202509.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202510.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202511.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202512.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202601.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202602.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202603.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202604.csv
# Column count: 82
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType']
# Extra columns: []
#
# Columns different: CRMLSListing202605.csv
# Column count: 81
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType', 'ListAgentEmail']
# Extra columns: []
#
# Columns different: CRMLSListing202606.csv
# Column count: 81
# Missing columns: ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType', 'ListAgentEmail']
# Extra columns: []
#
# Note: Some List files have different columns.
# This is okay if the differences come from filled files.
# When combining files, missing columns will be filled with NaN.

# %%
print_section("6. Required Column Check")

required_sold_cols = [
    "ListingKey",
    "ListingId",
    "CloseDate",
    "ClosePrice",
    "ListPrice",
    "City",
    "PostalCode",
    "Latitude",
    "Longitude",
    "PropertyType",
    "LivingArea",
    "BedroomsTotal",
    "BathroomsTotalInteger"
]

required_list_cols = [
    "ListingKey",
    "ListingId",
    "ListingContractDate",
    "ListPrice",
    "City",
    "PostalCode",
    "Latitude",
    "Longitude",
    "PropertyType",
    "LivingArea",
    "BedroomsTotal",
    "BathroomsTotalInteger"
]


def check_required_columns(files, required_cols, label):
    """
    Check whether each selected file contains the required columns for analysis.
    """
    print(f"\nChecking required columns for {label}...")

    all_good = True

    for file in files:
        df = pd.read_csv(file, nrows=0)
        cols = set(df.columns)
        missing = sorted(set(required_cols) - cols)

        if missing:
            all_good = False
            print(file.name, "missing:", missing)

    if all_good:
        print(f"All selected {label} files have required columns.")


check_required_columns(sold_files, required_sold_cols, "Sold")
check_required_columns(list_files, required_list_cols, "List")
# Out:
# --------------------------------------------------
# 6. Required Column Check
# --------------------------------------------------
#
# Checking required columns for Sold...
# All selected Sold files have required columns.
#
# Checking required columns for List...
# All selected List files have required columns.

# %%
print_section("7-1. Combine Files without filter property type = residential")


def combine_files(files, data_type):
    """
    Combine multiple CSV files into one DataFrame.
    Add source_file, year_month, data_type, and file_version columns for tracking.
    """
    all_dfs = []

    for file in files:
        print("Reading:", file.name)

        df = pd.read_csv(file, low_memory=False)

        # Add source information for tracking
        df["source_file"] = file.name
        df["year_month"] = extract_year_month(file)
        df["data_type"] = data_type
        df["file_version"] = "filled" if is_filled_file(file) else "original"

        all_dfs.append(df)

    if len(all_dfs) == 0:
        print(f"No files to combine for {data_type}.")
        return pd.DataFrame()

    combined_df = pd.concat(all_dfs, ignore_index=True, sort=False)

    return combined_df


sold_df = combine_files(sold_files, "sold")
list_df = combine_files(list_files, "list")

print("\nCombined sold shape:", sold_df.shape)
print("Combined list shape:", list_df.shape)

# Export combined Sold and List files separately
sold_output_path = output_dir / "combined_sold.csv"
list_output_path = output_dir / "combined_list.csv"

sold_df.to_csv(sold_output_path, index=False)
list_df.to_csv(list_output_path, index=False)

print("\nDone!")
print("Saved:", sold_output_path)
print("Saved:", list_output_path)

import pandas as pd
combined_sold = pd.read_csv("output/combined_sold.csv")

print(combined_sold.shape)
# Out:
# --------------------------------------------------
# 7-1. Combine Files without filter property type = residential
# --------------------------------------------------
# Reading: CRMLSSold202401.csv
# Reading: CRMLSSold202402.csv
# Reading: CRMLSSold202403.csv
# Reading: CRMLSSold202404.csv
# Reading: CRMLSSold202405_filled.csv
# Reading: CRMLSSold202406_filled.csv
# Reading: CRMLSSold202407_filled.csv
# Reading: CRMLSSold202408.csv
# Reading: CRMLSSold202409.csv
# Reading: CRMLSSold202410.csv
# Reading: CRMLSSold202411.csv
# Reading: CRMLSSold202412.csv
# Reading: CRMLSSold202501_filled.csv
# Reading: CRMLSSold202502.csv
# Reading: CRMLSSold202503.csv
# Reading: CRMLSSold202504.csv
# Reading: CRMLSSold202505.csv
# Reading: CRMLSSold202506.csv
# Reading: CRMLSSold202507.csv
# Reading: CRMLSSold202508.csv
# Reading: CRMLSSold202509.csv
# Reading: CRMLSSold202510.csv
# Reading: CRMLSSold202511.csv
# Reading: CRMLSSold202512.csv
# Reading: CRMLSSold202601.csv
# Reading: CRMLSSold202602.csv
# Reading: CRMLSSold202603.csv
# Reading: CRMLSSold202604.csv
# Reading: CRMLSSold202605.csv
# Reading: CRMLSSold202606.csv
# Reading: CRMLSListing202401.csv
# Reading: CRMLSListing202402.csv
# Reading: CRMLSListing202403.csv
# Reading: CRMLSListing202404.csv
# Reading: CRMLSListing202405.csv
# Reading: CRMLSListing202406.csv
# Reading: CRMLSListing202407.csv
# Reading: CRMLSListing202408.csv
# Reading: CRMLSListing202409.csv
# Reading: CRMLSListing202410.csv
# Reading: CRMLSListing202411.csv
# Reading: CRMLSListing202412.csv
# Reading: CRMLSListing202501.csv
# Reading: CRMLSListing202502.csv
# Reading: CRMLSListing202503.csv
# Reading: CRMLSListing202504.csv
# Reading: CRMLSListing202505.csv
# Reading: CRMLSListing202506.csv
# Reading: CRMLSListing202507.csv
# Reading: CRMLSListing202508.csv
# Reading: CRMLSListing202509.csv
# Reading: CRMLSListing202510.csv
# Reading: CRMLSListing202511.csv
# Reading: CRMLSListing202512.csv
# Reading: CRMLSListing202601.csv
# Reading: CRMLSListing202602.csv
# Reading: CRMLSListing202603.csv
# Reading: CRMLSListing202604.csv
# Reading: CRMLSListing202605.csv
# Reading: CRMLSListing202606.csv
#
# Combined sold shape: (665521, 88)
# Combined list shape: (967204, 88)
#
# Done!
# Saved: output/combined_sold.csv
# Saved: output/combined_list.csv
# /var/folders/4t/9h5f64517hv1hpxqqfq2xltw0000gn/T/ipykernel_1746/2207115190.py:51: DtypeWarning: Columns (0,1,4,9,78,79,84,86,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_sold = pd.read_csv("output/combined_sold.csv")
# (665521, 88)

# %%
print_section("7-2. Combine Files and Filter Residential")

def combine_files(files, data_type):
    """
    Combine multiple CSV files into one DataFrame.
    Add source_file, year_month, data_type, and file_version columns for tracking.
    Print row counts before and after Residential filter for each monthly file.
    """
    all_dfs = []
    row_counts_before = []
    row_counts_after_residential = []

    for file in files:
        print("Reading:", file.name)

        df = pd.read_csv(file, low_memory=False)

        rows_before = len(df)

        if "PropertyType" not in df.columns:
            raise ValueError(f"PropertyType column is missing in {file.name}")

        # Filter each monthly file to Residential only
        df_residential = df[
            df["PropertyType"].astype(str).str.strip().eq("Residential")
        ].copy()

        rows_after = len(df_residential)

        row_counts_before.append(rows_before)
        row_counts_after_residential.append(rows_after)

        print(f"{file.name}:")
        print(f"  Rows before Residential filter: {rows_before}")
        print(f"  Rows after Residential filter: {rows_after}")
        print(f"  Rows removed: {rows_before - rows_after}")

        # Add source information for tracking
        df_residential["source_file"] = file.name
        df_residential["year_month"] = extract_year_month(file)
        df_residential["data_type"] = data_type
        df_residential["file_version"] = "filled" if is_filled_file(file) else "original"

        all_dfs.append(df_residential)

    if len(all_dfs) == 0:
        print(f"No files to combine for {data_type}.")
        return pd.DataFrame()

    # Row count before concatenation after Residential filter
    rows_before_concat = sum(row_counts_after_residential)

    combined_df = pd.concat(all_dfs, ignore_index=True, sort=False)

    # Row count after concatenation
    rows_after_concat = len(combined_df)

    print(f"\n{data_type} total rows before Residential filter:", sum(row_counts_before))
    print(f"{data_type} total rows after Residential filter:", sum(row_counts_after_residential))

    print(f"\n{data_type} rows before concatenation:", rows_before_concat)
    print(f"{data_type} rows after concatenation:", rows_after_concat)

    if rows_before_concat == rows_after_concat:
        print(f"{data_type} concatenation row count check: PASS")
    else:
        print(f"{data_type} concatenation row count check: FAIL")

    return combined_df

sold_df = combine_files(sold_files, "sold")
list_df = combine_files(list_files, "list")

print("\nFinal sold shape:", sold_df.shape)
print("Final list shape:", list_df.shape)

sold_output_path = output_dir / "combined_sold_residential.csv"
list_output_path = output_dir / "combined_list_residential.csv"

sold_df.to_csv(sold_output_path, index=False)
list_df.to_csv(list_output_path, index=False)

print("\nDone!")
print("Saved:", sold_output_path)
print("Saved:", list_output_path)
# Out:
# --------------------------------------------------
# 7-2. Combine Files and Filter Residential
# --------------------------------------------------
# Reading: CRMLSSold202401.csv
# CRMLSSold202401.csv:
#   Rows before Residential filter: 17976
#   Rows after Residential filter: 11203
#   Rows removed: 6773
# Reading: CRMLSSold202402.csv
# CRMLSSold202402.csv:
#   Rows before Residential filter: 19925
#   Rows after Residential filter: 13063
#   Rows removed: 6862
# Reading: CRMLSSold202403.csv
# CRMLSSold202403.csv:
#   Rows before Residential filter: 23276
#   Rows after Residential filter: 15784
#   Rows removed: 7492
# Reading: CRMLSSold202404.csv
# CRMLSSold202404.csv:
#   Rows before Residential filter: 24640
#   Rows after Residential filter: 17295
#   Rows removed: 7345
# Reading: CRMLSSold202405_filled.csv
# CRMLSSold202405_filled.csv:
#   Rows before Residential filter: 26487
#   Rows after Residential filter: 18474
#   Rows removed: 8013
# Reading: CRMLSSold202406_filled.csv
# CRMLSSold202406_filled.csv:
#   Rows before Residential filter: 24328
#   Rows after Residential filter: 16625
#   Rows removed: 7703
# Reading: CRMLSSold202407_filled.csv
# CRMLSSold202407_filled.csv:
#   Rows before Residential filter: 26240
#   Rows after Residential filter: 17809
#   Rows removed: 8431
# Reading: CRMLSSold202408.csv
# CRMLSSold202408.csv:
#   Rows before Residential filter: 24558
#   Rows after Residential filter: 16791
#   Rows removed: 7767
# Reading: CRMLSSold202409.csv
# CRMLSSold202409.csv:
#   Rows before Residential filter: 21267
#   Rows after Residential filter: 14555
#   Rows removed: 6712
# Reading: CRMLSSold202410.csv
# CRMLSSold202410.csv:
#   Rows before Residential filter: 23274
#   Rows after Residential filter: 16275
#   Rows removed: 6999
# Reading: CRMLSSold202411.csv
# CRMLSSold202411.csv:
#   Rows before Residential filter: 20279
#   Rows after Residential filter: 14158
#   Rows removed: 6121
# Reading: CRMLSSold202412.csv
# CRMLSSold202412.csv:
#   Rows before Residential filter: 20241
#   Rows after Residential filter: 14220
#   Rows removed: 6021
# Reading: CRMLSSold202501_filled.csv
# CRMLSSold202501_filled.csv:
#   Rows before Residential filter: 18738
#   Rows after Residential filter: 10976
#   Rows removed: 7762
# Reading: CRMLSSold202502.csv
# CRMLSSold202502.csv:
#   Rows before Residential filter: 18702
#   Rows after Residential filter: 12101
#   Rows removed: 6601
# Reading: CRMLSSold202503.csv
# CRMLSSold202503.csv:
#   Rows before Residential filter: 21445
#   Rows after Residential filter: 14409
#   Rows removed: 7036
# Reading: CRMLSSold202504.csv
# CRMLSSold202504.csv:
#   Rows before Residential filter: 23262
#   Rows after Residential filter: 15851
#   Rows removed: 7411
# Reading: CRMLSSold202505.csv
# CRMLSSold202505.csv:
#   Rows before Residential filter: 23154
#   Rows after Residential filter: 15544
#   Rows removed: 7610
# Reading: CRMLSSold202506.csv
# CRMLSSold202506.csv:
#   Rows before Residential filter: 22883
#   Rows after Residential filter: 15329
#   Rows removed: 7554
# Reading: CRMLSSold202507.csv
# CRMLSSold202507.csv:
#   Rows before Residential filter: 23646
#   Rows after Residential filter: 15800
#   Rows removed: 7846
# Reading: CRMLSSold202508.csv
# CRMLSSold202508.csv:
#   Rows before Residential filter: 22972
#   Rows after Residential filter: 15225
#   Rows removed: 7747
# Reading: CRMLSSold202509.csv
# CRMLSSold202509.csv:
#   Rows before Residential filter: 22443
#   Rows after Residential filter: 15134
#   Rows removed: 7309
# Reading: CRMLSSold202510.csv
# CRMLSSold202510.csv:
#   Rows before Residential filter: 23233
#   Rows after Residential filter: 15897
#   Rows removed: 7336
# Reading: CRMLSSold202511.csv
# CRMLSSold202511.csv:
#   Rows before Residential filter: 19088
#   Rows after Residential filter: 12978
#   Rows removed: 6110
# Reading: CRMLSSold202512.csv
# CRMLSSold202512.csv:
#   Rows before Residential filter: 20538
#   Rows after Residential filter: 13975
#   Rows removed: 6563
# Reading: CRMLSSold202601.csv
# CRMLSSold202601.csv:
#   Rows before Residential filter: 16487
#   Rows after Residential filter: 10083
#   Rows removed: 6404
# Reading: CRMLSSold202602.csv
# CRMLSSold202602.csv:
#   Rows before Residential filter: 19010
#   Rows after Residential filter: 12272
#   Rows removed: 6738
# Reading: CRMLSSold202603.csv
# CRMLSSold202603.csv:
#   Rows before Residential filter: 23372
#   Rows after Residential filter: 15656
#   Rows removed: 7716
# Reading: CRMLSSold202604.csv
# CRMLSSold202604.csv:
#   Rows before Residential filter: 24261
#   Rows after Residential filter: 16581
#   Rows removed: 7680
# Reading: CRMLSSold202605.csv
# CRMLSSold202605.csv:
#   Rows before Residential filter: 24195
#   Rows after Residential filter: 16384
#   Rows removed: 7811
# Reading: CRMLSSold202606.csv
# CRMLSSold202606.csv:
#   Rows before Residential filter: 25601
#   Rows after Residential filter: 17586
#   Rows removed: 8015
#
# sold total rows before Residential filter: 665521
# sold total rows after Residential filter: 448033
#
# sold rows before concatenation: 448033
# sold rows after concatenation: 448033
# sold concatenation row count check: PASS
# Reading: CRMLSListing202401.csv
# CRMLSListing202401.csv:
#   Rows before Residential filter: 27454
#   Rows after Residential filter: 17007
#   Rows removed: 10447
# Reading: CRMLSListing202402.csv
# CRMLSListing202402.csv:
#   Rows before Residential filter: 27447
#   Rows after Residential filter: 17490
#   Rows removed: 9957
# Reading: CRMLSListing202403.csv
# CRMLSListing202403.csv:
#   Rows before Residential filter: 32282
#   Rows after Residential filter: 20501
#   Rows removed: 11781
# Reading: CRMLSListing202404.csv
# CRMLSListing202404.csv:
#   Rows before Residential filter: 36503
#   Rows after Residential filter: 24025
#   Rows removed: 12478
# Reading: CRMLSListing202405.csv
# CRMLSListing202405.csv:
#   Rows before Residential filter: 38796
#   Rows after Residential filter: 25447
#   Rows removed: 13349
# Reading: CRMLSListing202406.csv
# CRMLSListing202406.csv:
#   Rows before Residential filter: 35893
#   Rows after Residential filter: 23310
#   Rows removed: 12583
# Reading: CRMLSListing202407.csv
# CRMLSListing202407.csv:
#   Rows before Residential filter: 36340
#   Rows after Residential filter: 23019
#   Rows removed: 13321
# Reading: CRMLSListing202408.csv
# CRMLSListing202408.csv:
#   Rows before Residential filter: 35305
#   Rows after Residential filter: 22215
#   Rows removed: 13090
# Reading: CRMLSListing202409.csv
# CRMLSListing202409.csv:
#   Rows before Residential filter: 34625
#   Rows after Residential filter: 22257
#   Rows removed: 12368
# Reading: CRMLSListing202410.csv
# CRMLSListing202410.csv:
#   Rows before Residential filter: 34730
#   Rows after Residential filter: 21921
#   Rows removed: 12809
# Reading: CRMLSListing202411.csv
# CRMLSListing202411.csv:
#   Rows before Residential filter: 25128
#   Rows after Residential filter: 15108
#   Rows removed: 10020
# Reading: CRMLSListing202412.csv
# CRMLSListing202412.csv:
#   Rows before Residential filter: 19417
#   Rows after Residential filter: 10694
#   Rows removed: 8723
# Reading: CRMLSListing202501.csv
# CRMLSListing202501.csv:
#   Rows before Residential filter: 37469
#   Rows after Residential filter: 22690
#   Rows removed: 14779
# Reading: CRMLSListing202502.csv
# CRMLSListing202502.csv:
#   Rows before Residential filter: 33983
#   Rows after Residential filter: 21930
#   Rows removed: 12053
# Reading: CRMLSListing202503.csv
# CRMLSListing202503.csv:
#   Rows before Residential filter: 38492
#   Rows after Residential filter: 25104
#   Rows removed: 13388
# Reading: CRMLSListing202504.csv
# CRMLSListing202504.csv:
#   Rows before Residential filter: 40187
#   Rows after Residential filter: 26695
#   Rows removed: 13492
# Reading: CRMLSListing202505.csv
# CRMLSListing202505.csv:
#   Rows before Residential filter: 40271
#   Rows after Residential filter: 26438
#   Rows removed: 13833
# Reading: CRMLSListing202506.csv
# CRMLSListing202506.csv:
#   Rows before Residential filter: 26399
#   Rows after Residential filter: 17056
#   Rows removed: 9343
# Reading: CRMLSListing202507.csv
# CRMLSListing202507.csv:
#   Rows before Residential filter: 27345
#   Rows after Residential filter: 17194
#   Rows removed: 10151
# Reading: CRMLSListing202508.csv
# CRMLSListing202508.csv:
#   Rows before Residential filter: 25210
#   Rows after Residential filter: 15658
#   Rows removed: 9552
# Reading: CRMLSListing202509.csv
# CRMLSListing202509.csv:
#   Rows before Residential filter: 26923
#   Rows after Residential filter: 16859
#   Rows removed: 10064
# Reading: CRMLSListing202510.csv
# CRMLSListing202510.csv:
#   Rows before Residential filter: 27586
#   Rows after Residential filter: 17186
#   Rows removed: 10400
# Reading: CRMLSListing202511.csv
# CRMLSListing202511.csv:
#   Rows before Residential filter: 20677
#   Rows after Residential filter: 12194
#   Rows removed: 8483
# Reading: CRMLSListing202512.csv
# CRMLSListing202512.csv:
#   Rows before Residential filter: 18773
#   Rows after Residential filter: 10516
#   Rows removed: 8257
# Reading: CRMLSListing202601.csv
# CRMLSListing202601.csv:
#   Rows before Residential filter: 35302
#   Rows after Residential filter: 22108
#   Rows removed: 13194
# Reading: CRMLSListing202602.csv
# CRMLSListing202602.csv:
#   Rows before Residential filter: 32884
#   Rows after Residential filter: 20823
#   Rows removed: 12061
# Reading: CRMLSListing202603.csv
# CRMLSListing202603.csv:
#   Rows before Residential filter: 39153
#   Rows after Residential filter: 25614
#   Rows removed: 13539
# Reading: CRMLSListing202604.csv
# CRMLSListing202604.csv:
#   Rows before Residential filter: 39020
#   Rows after Residential filter: 26490
#   Rows removed: 12530
# Reading: CRMLSListing202605.csv
# CRMLSListing202605.csv:
#   Rows before Residential filter: 36115
#   Rows after Residential filter: 24019
#   Rows removed: 12096
# Reading: CRMLSListing202606.csv
# CRMLSListing202606.csv:
#   Rows before Residential filter: 37495
#   Rows after Residential filter: 24171
#   Rows removed: 13324
#
# list total rows before Residential filter: 967204
# list total rows after Residential filter: 615739
#
# list rows before concatenation: 615739
# list rows after concatenation: 615739
# list concatenation row count check: PASS
#
# Final sold shape: (448033, 88)
# Final list shape: (615739, 88)
#
# Done!
# Saved: output/combined_sold_residential.csv
# Saved: output/combined_list_residential.csv

# %%
print_section("8. Check different columns between original data and combined data")

from pathlib import Path
import pandas as pd

output_dir = Path("output")

combined_sold = pd.read_csv(output_dir / "combined_sold_residential.csv", low_memory=False)

print("Combined Sold Residential shape:", combined_sold.shape)
# Out:
# --------------------------------------------------
# 8. Check different columns between original data and combined data
# --------------------------------------------------
# Combined Sold Residential shape: (448033, 88)

# %%
sold_column_summary = pd.DataFrame({
    "column": combined_sold.columns,
    "dtype": combined_sold.dtypes.astype(str),
    "non_null_count": combined_sold.notna().sum().values,
    "missing_count": combined_sold.isna().sum().values,
    "missing_percent": (combined_sold.isna().mean() * 100).round(2).values,
    "unique_count": combined_sold.nunique(dropna=True).values
})

# Sort by missing percent from highest to lowest
sold_column_summary = sold_column_summary.sort_values(
    by="missing_percent",
    ascending=False
)

print(sold_column_summary.to_string(index=False))
# Out:
#                       column   dtype  non_null_count  missing_count  missing_percent  unique_count
#                CoveredSpaces float64               0         448033           100.00             0
#              TaxAnnualAmount float64               0         448033           100.00             0
#     ElementarySchoolDistrict float64               0         448033           100.00             0
#                 BusinessType float64               0         448033           100.00             0
#              FireplacesTotal float64               0         448033           100.00             0
#                      TaxYear float64               0         448033           100.00             0
# MiddleOrJuniorSchoolDistrict float64               0         448033           100.00             0
#       AboveGradeFinishedArea float64               0         448033           100.00             0
#                 WaterfrontYN  object             287         447746            99.94             1
#       BelowGradeFinishedArea float64            2656         445377            99.41           166
#                   BasementYN  object            8783         439250            98.04             1
#            LotSizeDimensions  object           21822         426211            95.13         10664
#                  BuilderName  object           21944         426089            95.10          3572
#            BuildingAreaTotal float64           31457         416576            92.98          5101
#        CoBuyerAgentFirstName  object           41056         406977            90.84          4586
#  BuyerAgencyCompensationType  object           46136         401897            89.70             3
#      BuyerAgencyCompensation float64           46125         401908            89.70           174
#             ElementarySchool  object           59523         388510            86.71          1409
#         MiddleOrJuniorSchool  object           59945         388088            86.62           662
#                    lonfilled  object           63884         384149            85.74             2
#                    latfilled  object           63884         384149            85.74             2
#                   HighSchool  object           77857         370176            82.62           521
#        OriginatingSystemName  object           89682         358351            79.98             1
#     OriginatingSystemSubName  object           89682         358351            79.98            10
#         CoListAgentFirstName  object          102860         345173            77.04          6905
#          CoListAgentLastName  object          103129         344904            76.98         14439
#             CoListOfficeName  object          105992         342041            76.34          5753
#              SubdivisionName  object          166969         281064            62.73         16516
#      AssociationFeeFrequency  object          186584         261449            58.35             4
#            MainLevelBedrooms float64          259902         188131            41.99            37
#                     Flooring  object          287323         160710            35.87           340
#           HighSchoolDistrict  object          324487         123546            27.58           446
#               AssociationFee float64          345382         102651            22.91         10752
#                      Stories float64          379502          68531            15.30             2
#             AttachedGarageYN  object          379563          68470            15.28             2
#                 MLSAreaMajor  object          387702          60331            13.47          1091
#                BuyerAgentAOR  object          393496          54537            12.17            63
#                 ListAgentAOR  object          401831          46202            10.31            61
#                       Levels  object          405321          42712             9.53            19
#                       ViewYN  object          409603          38430             8.58             2
#                PoolPrivateYN  object          409778          38255             8.54             2
#               ListAgentEmail  object          413002          35031             7.82         83447
#                 LotSizeAcres float64          413278          34755             7.76         21419
#            LotSizeSquareFeet float64          413708          34325             7.66         42534
#                  LotSizeArea float64          413840          34193             7.63         42468
#            NewConstructionYN  object          414614          33419             7.46             2
#               BuyerOfficeAOR  object          420883          27150             6.06            69
#                 GarageSpaces float64          428770          19263             4.30            55
#                    Longitude float64          431812          16221             3.62        375650
#                     Latitude float64          431812          16221             3.62        366582
#              BuyerOfficeName  object          440881           7152             1.60         21874
#           ListAgentFirstName  object          444711           3322             0.74         15826
#          BuyerAgentFirstName  object          445908           2125             0.47         19736
#              PropertySubType  object          447173            860             0.19            20
#            OriginalListPrice float64          447211            822             0.18         21139
#              BuyerAgentMlsId  object          447448            585             0.13        120792
#     ContractStatusChangeDate  object          447444            589             0.13           909
#          StreetNumberNumeric float64          447491            542             0.12         48689
#              UnparsedAddress  object          447591            442             0.10        435101
#                 ParkingTotal float64          447607            426             0.10           253
#                    YearBuilt float64          447633            400             0.09           168
#                  FireplaceYN  object          447674            359             0.08             2
#                         City  object          447716            317             0.07          1145
#                   LivingArea float64          447780            253             0.06          7399
#           BuyerAgentLastName  object          447840            193             0.04         41015
#         PurchaseContractDate  object          447835            198             0.04          1227
#        BathroomsTotalInteger float64          447963             70             0.02            30
#            ListAgentFullName  object          447937             96             0.02         80189
#            ListAgentLastName  object          447993             40             0.01         35373
#               CountyOrParish  object          448033              0             0.00            63
#                 file_version  object          448033              0             0.00             2
#                    data_type  object          448033              0             0.00             1
#                   year_month   int64          448033              0             0.00            30
#            ListingKeyNumeric   int64          448033              0             0.00        447659
#                  source_file  object          448033              0             0.00            30
#                   ListingKey   int64          448033              0             0.00        447659
#                BedroomsTotal float64          448021             12             0.00            27
#                    MlsStatus  object          448033              0             0.00             1
#               ListOfficeName  object          448033              0             0.00         19160
#                   PostalCode  object          448029              4             0.00          3852
#                 DaysOnMarket   int64          448033              0             0.00           697
#                    CloseDate  object          448033              0             0.00           909
#                    ListingId  object          448033              0             0.00        447657
#                   ClosePrice float64          448031              2             0.00         27908
#              StateOrProvince  object          448032              1             0.00            15
#                    ListPrice float64          448033              0             0.00         20451
#                 PropertyType  object          448033              0             0.00             1
#          ListingContractDate  object          448032              1             0.00          1516

# %%
combined_list = pd.read_csv(output_dir / "combined_list_residential.csv", low_memory=False)

print("Combined List Residential shape:", combined_list.shape)
# Out:
# Combined List Residential shape: (615739, 88)

# %%
list_column_summary = pd.DataFrame({
    "column": combined_list.columns,
    "dtype": combined_list.dtypes.astype(str),
    "non_null_count": combined_list.notna().sum().values,
    "missing_count": combined_list.isna().sum().values,
    "missing_percent": (combined_list.isna().mean() * 100).round(2).values,
    "unique_count": combined_list.nunique(dropna=True).values
})

# Sort by missing percent from highest to lowest
list_column_summary = list_column_summary.sort_values(
    by="missing_percent",
    ascending=False
)

print(list_column_summary.to_string(index=False))
# Out:
#                       column   dtype  non_null_count  missing_count  missing_percent  unique_count
# MiddleOrJuniorSchoolDistrict float64               0         615739           100.00             0
#     ElementarySchoolDistrict float64               0         615739           100.00             0
#                 BusinessType float64               0         615739           100.00             0
#                      TaxYear float64               0         615739           100.00             0
#       AboveGradeFinishedArea float64               0         615739           100.00             0
#              FireplacesTotal float64               0         615739           100.00             0
#                CoveredSpaces float64               0         615739           100.00             0
#              TaxAnnualAmount float64               0         615739           100.00             0
#       BelowGradeFinishedArea float64            3545         612194            99.42           217
#        CoBuyerAgentFirstName  object           14772         600967            97.60          2838
#                  BuilderName  object           28315         587424            95.40          4152
#            LotSizeDimensions  object           32271         583468            94.76         13240
#            BuildingAreaTotal float64           55037         560702            91.06          6343
#             ElementarySchool  object           73344         542395            88.09          1440
#         MiddleOrJuniorSchool  object           73416         542323            88.08           674
#      BuyerAgencyCompensation float64           78993         536746            87.17           211
#  BuyerAgencyCompensationType  object           79013         536726            87.17             3
#                   HighSchool  object           96218         519521            84.37           531
#         CoListAgentFirstName  object          137415         478324            77.68          7843
#          CoListAgentLastName  object          137875         477864            77.61         16219
#             CoListOfficeName  object          137976         477763            77.59          6493
#                   ClosePrice float64          146752         468987            76.17         12114
#               BuyerOfficeAOR  object          149893         465846            75.66            66
#              BuyerOfficeName  object          160736         455003            73.90         13912
#            BuyerOfficeName.1  object          160736         455003            73.90         13912
#          BuyerAgentFirstName  object          162274         453465            73.65         13904
#              BuyerAgentMlsId  object          162916         452823            73.54         72666
#           BuyerAgentLastName  object          163028         452711            73.52         28396
#                  CloseDate.1  object          170655         445084            72.28           990
#                    CloseDate  object          170655         445084            72.28           990
#              SubdivisionName  object          226019         389720            63.29         18187
#      AssociationFeeFrequency  object          263876         351863            57.14             4
#         PurchaseContractDate  object          289065         326674            53.05           923
#            MainLevelBedrooms float64          334129         281610            45.74            39
#           HighSchoolDistrict  object          430387         185352            30.10           455
#               AssociationFee float64          467441         148298            24.08         13740
#                      Stories float64          507633         108106            17.56             2
#             AttachedGarageYN  object          507884         107855            17.52             2
#                 MLSAreaMajor  object          532038          83701            13.59          1114
#                   Latitude.1 float64          534739          81000            13.15        391919
#                  Longitude.1 float64          534739          81000            13.15        411014
#                     Latitude float64          534739          81000            13.15        391919
#                    Longitude float64          534739          81000            13.15        411014
#                       Levels  object          548877          66862            10.86            18
#                 LotSizeAcres float64          565415          50324             8.17         24435
#               ListAgentEmail  object          565985          49754             8.08         94724
#            LotSizeSquareFeet float64          566153          49586             8.05         48668
#                  LotSizeArea float64          566351          49388             8.02         48566
#            NewConstructionYN  object          573407          42332             6.87             2
#                 GarageSpaces float64          581426          34313             5.57            65
#     ContractStatusChangeDate  object          608492           7247             1.18           943
#         ListAgentFirstName.1  object          610925           4814             0.78         17693
#           ListAgentFirstName  object          610925           4814             0.78         17693
#              PropertySubType  object          614325           1414             0.23            21
#          StreetNumberNumeric float64          614605           1134             0.18         52121
#                    YearBuilt float64          614676           1063             0.17           175
#              UnparsedAddress  object          614819            920             0.15        537500
#            UnparsedAddress.1  object          614819            920             0.15        537500
#            OriginalListPrice float64          614864            875             0.14         26351
#                  FireplaceYN  object          615085            654             0.11             2
#                   LivingArea float64          615116            623             0.10          8699
#                         City  object          615135            604             0.10          1233
#                 LivingArea.1 float64          615116            623             0.10          8699
#                BedroomsTotal float64          615575            164             0.03            42
#            ListAgentFullName  object          615630            109             0.02         90287
#              StateOrProvince  object          615676             63             0.01            28
#        BathroomsTotalInteger float64          615682             57             0.01            41
#            ListAgentLastName  object          615697             42             0.01         38723
#          ListAgentLastName.1  object          615697             42             0.01         38723
#                 DaysOnMarket   int64          615739              0             0.00           343
#                    ListPrice float64          615739              0             0.00         26056
#          ListingContractDate  object          615739              0             0.00           912
#                 PropertyType  object          615739              0             0.00             1
#                   PostalCode  object          615718             21             0.00          4710
#                   year_month   int64          615739              0             0.00            30
#                    data_type  object          615739              0             0.00             1
#                  source_file  object          615739              0             0.00            30
#               PropertyType.1  object          615739              0             0.00             1
#               ListOfficeName  object          615739              0             0.00         21586
#            ListingKeyNumeric   int64          615739              0             0.00        615550
#               CountyOrParish  object          615739              0             0.00            63
#                    MlsStatus  object          615739              0             0.00             5
#                 ParkingTotal float64          615719             20             0.00           319
#               DaysOnMarket.1   int64          615739              0             0.00           343
#                   ListingKey   int64          615739              0             0.00        615550
#                    ListingId  object          615739              0             0.00        615530
#                  ListPrice.1 float64          615739              0             0.00         26056
#                 file_version  object          615739              0             0.00             1

# %%
def find_column_differences(files, label):
    columns_by_file = {}

    for file in files:
        cols = pd.read_csv(file, nrows=0).columns.tolist()
        columns_by_file[file.name] = set(cols)

    all_columns = sorted(set().union(*columns_by_file.values()))
    common_columns = sorted(set.intersection(*columns_by_file.values()))

    print(f"\n{label} files:", len(files))
    print(f"{label} union column count:", len(all_columns))
    print(f"{label} common column count:", len(common_columns))
    print(f"{label} columns not in every file:", len(set(all_columns) - set(common_columns)))

    result = []

    for col in all_columns:
        present_in = [
            file_name for file_name, cols in columns_by_file.items()
            if col in cols
        ]

        missing_in = [
            file_name for file_name, cols in columns_by_file.items()
            if col not in cols
        ]

        if missing_in:
            result.append({
                "column": col,
                "present_count": len(present_in),
                "missing_count": len(missing_in),
                "present_in": present_in,
                "missing_in": missing_in
            })

    diff_df = pd.DataFrame(result)

    return diff_df

# %%
sold_column_diff = find_column_differences(sold_files, "Sold")
list_column_diff = find_column_differences(list_files, "List")

print("\nSold column differences:")
print(sold_column_diff[["column", "present_count", "missing_count"]].to_string(index=False))

print("\nList column differences:")
print(list_column_diff[["column", "present_count", "missing_count"]].to_string(index=False))
# Out:
# Sold files: 30
# Sold union column count: 84
# Sold common column count: 75
# Sold columns not in every file: 9
#
# List files: 30
# List union column count: 84
# List common column count: 81
# List columns not in every file: 3
#
# Sold column differences:
#                      column  present_count  missing_count
#     BuyerAgencyCompensation              3             27
# BuyerAgencyCompensationType              3             27
#               BuyerAgentAOR             27              3
#                ListAgentAOR             27              3
#              ListAgentEmail             28              2
#       OriginatingSystemName              6             24
#    OriginatingSystemSubName              6             24
#                   latfilled              4             26
#                   lonfilled              4             26
#
# List column differences:
#                      column  present_count  missing_count
#     BuyerAgencyCompensation              4             26
# BuyerAgencyCompensationType              4             26
#              ListAgentEmail             28              2

# %%
# check extra cols in combined_list_residential.csv
from pathlib import Path
import pandas as pd

data_dir = Path("csv")
output_dir = Path("output")

base_file = data_dir / "CRMLSListing202401.csv"

base_cols = set(pd.read_csv(base_file, nrows=0).columns)
combined_list_cols = set(pd.read_csv(output_dir / "combined_list_residential.csv", nrows=0).columns)

extra_in_combined = sorted(combined_list_cols - base_cols)
missing_from_combined = sorted(base_cols - combined_list_cols)

print("Base column count:", len(base_cols))
print("Combined List column count:", len(combined_list_cols))

print("\nColumns in combined_list but not in base file:")
print(extra_in_combined)

print("\nColumns in base file but not in combined_list:")
print(missing_from_combined)
# Out:
# Base column count: 84
# Combined List column count: 88
#
# Columns in combined_list but not in base file:
# ['data_type', 'file_version', 'source_file', 'year_month']
#
# Columns in base file but not in combined_list:
# []

# %%
# check extra cols from combined_sold_residential.csv
from pathlib import Path
import pandas as pd

data_dir = Path("csv")
output_dir = Path("output")

# select Sold's base file
base_file = data_dir / "CRMLSSold202401.csv"

base_cols = set(pd.read_csv(base_file, nrows=0).columns)
combined_sold_cols = set(pd.read_csv(output_dir / "combined_sold_residential.csv", nrows=0).columns)

extra_in_combined_sold = sorted(combined_sold_cols - base_cols)
missing_from_combined_sold = sorted(base_cols - combined_sold_cols)

print("Base Sold column count:", len(base_cols))
print("Combined Sold column count:", len(combined_sold_cols))

print("\nColumns in combined_sold but not in base Sold file:")
print(extra_in_combined_sold)

print("\nColumns in base Sold file but not in combined_sold:")
print(missing_from_combined_sold)
# Out:
# Base Sold column count: 80
# Combined Sold column count: 88
#
# Columns in combined_sold but not in base Sold file:
# ['BuyerAgencyCompensation', 'BuyerAgencyCompensationType', 'data_type', 'file_version', 'latfilled', 'lonfilled', 'source_file', 'year_month']
#
# Columns in base Sold file but not in combined_sold:
# []

# %%
print("Combined Sold Residential shape:", combined_sold.shape)
print("Combined List Residential shape:", combined_list.shape)
# Out:
# Combined Sold Residential shape: (448033, 88)
# Combined List Residential shape: (615739, 88)

# %%
import pandas as pd
df_sold_2606 = pd.read_csv("csv/CRMLSSold202606.csv")
df_list_2606 = pd.read_csv("csv/CRMLSListing202606.csv")

# %%
print(df_sold_2606.shape)
print(df_list_2606.shape)
# Out:
# (25601, 79)
# (37495, 81)
